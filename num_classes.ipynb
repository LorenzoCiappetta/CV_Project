# %%
import os
import numpy as np
from PIL import Image
import glob
from sklearn.cluster import KMeans
from collections import Counter

def count_classes_in_segmentation_maps(folder_path, color_tolerance=10, max_clusters=50):
    """
    Count the maximum number of unique classes in segmentation maps.
    Groups similar colors together to avoid counting compression artifacts.
    
    Args:
        folder_path (str): Path to the folder containing segmentation maps
        color_tolerance (int): Distance threshold for considering colors as same (0-255)
        max_clusters (int): Maximum number of clusters to consider
    
    Returns:
        tuple: (max_classes, max_classes_image, all_class_counts)
    """
    # Get all image files in the folder
    ext = '*.png'
    image_files = []

    image_files.extend(glob.glob(os.path.join(folder_path, ext)))
    
    if not image_files:
        print(f"No image files found in {folder_path}")
        return 0, None, []
    
    max_classes = 0
    max_classes_image = None
    all_class_counts = []
    
    print(f"Processing {len(image_files)} images...")
    print(f"Using color tolerance: {color_tolerance}")
    
    for i, image_path in enumerate(image_files):
        try:
            # Load the image
            img = Image.open(image_path)
            
            # Convert to numpy array
            img_array = np.array(img)
            
            # Handle different image formats
            if len(img_array.shape) == 3:
                # RGB image - group similar colors
                num_classes = count_clustered_colors(img_array, color_tolerance, max_clusters)
            else:
                print("WARNING: **********GRAYSCALE DETECTED**********")
                # Grayscale image - group similar values
                unique_values = np.unique(img_array)
                num_classes = len(unique_values)
            
            all_class_counts.append((os.path.basename(image_path), num_classes))
            
            if num_classes > max_classes:
                max_classes = num_classes
                max_classes_image = image_path
            
            # Print progress every 10 images
            if (i + 1) % 10 == 0:
                print(f"Processed {i + 1}/{len(image_files)} images...")
                
        except Exception as e:
            print(f"Error processing {image_path}: {e}")
            continue
    
    return max_classes, max_classes_image, all_class_counts

def count_clustered_colors(img_array, tolerance=10, max_clusters=50):
    """
    Count unique colors by clustering similar colors together.
    
    Args:
        img_array: numpy array of the image
        tolerance: color distance threshold
        max_clusters: maximum number of clusters to consider
    
    Returns:
        int: number of unique color clusters
    """
    # Flatten the image to get all pixels
    pixels = img_array.reshape(-1, img_array.shape[-1])
    
    # Get unique colors first
    unique_colors = np.unique(pixels, axis=0)
    
    # If we have few unique colors, no need to cluster
    if len(unique_colors) <= max_clusters:
        return len(unique_colors)
    
    # Use K-means clustering to group similar colors
    # Start with a reasonable number of clusters
    n_clusters = min(max_clusters, len(unique_colors))
    
    try:
        # Perform clustering
        kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
        kmeans.fit(unique_colors)
        
        # Count unique cluster centers
        return len(np.unique(kmeans.labels_))
    except:
        # Fallback to simpler method if clustering fails
        return count_colors_by_distance(unique_colors, tolerance)

def count_colors_by_distance(colors, tolerance=10):
    """
    Count unique colors by grouping colors within a distance threshold.
    
    Args:
        colors: array of unique colors
        tolerance: distance threshold for grouping
    
    Returns:
        int: number of unique color groups
    """
    if len(colors) == 0:
        return 0
    
    # Group colors by distance
    color_groups = []
    
    for color in colors:
        # Check if this color is close to any existing group
        assigned = False
        for group in color_groups:
            # Calculate Euclidean distance to group representative
            distance = np.linalg.norm(color - group)
            if distance <= tolerance:
                assigned = True
                break
        
        # If not assigned to any group, create a new group
        if not assigned:
            color_groups.append(color)
    
    return len(color_groups)

def analyze_specific_image(image_path, color_tolerance=10, max_clusters=50):
    """
    Analyze a specific image to see its unique classes/colors.
    
    Args:
        image_path (str): Path to the image
        color_tolerance (int): Distance threshold for grouping colors
        max_clusters (int): Maximum clusters to consider
    """
    try:
        img = Image.open(image_path)
        img_array = np.array(img)
        
        print(f"\nAnalyzing: {os.path.basename(image_path)}")
        print(f"Image shape: {img_array.shape}")
        
        if len(img_array.shape) == 3:
            # RGB image
            pixels = img_array.reshape(-1, img_array.shape[-1])
            unique_colors = np.unique(pixels, axis=0)
            
            print(f"Raw unique colors: {len(unique_colors)}")
            
            # Group similar colors
            clustered_count = count_clustered_colors(img_array, color_tolerance, max_clusters)
            print(f"Clustered unique colors (tolerance={color_tolerance}): {clustered_count}")
            
            # Show most common colors
            color_counts = Counter(map(tuple, pixels))
            most_common = color_counts.most_common(10)
            
            print("Most common colors:")
            for i, (color, count) in enumerate(most_common):
                percentage = (count / len(pixels)) * 100
                print(f"  {i+1}. RGB{color}: {count} pixels ({percentage:.1f}%)")
                
        else:
            # Grayscale image
            unique_values = np.unique(img_array)
            print(f"Number of unique values: {len(unique_values)}")
            print("Unique values:", unique_values[:20])  # Show first 20 values
            
    except Exception as e:
        print(f"Error analyzing {image_path}: {e}")

# Main execution
if __name__ == "__main__":
    # Set your folder path here
    folder_path = "./CVUSA_subset/polarmap/segmap/"  # Change this to your actual folder path
    
    # Adjust these parameters based on your needs
    color_tolerance = 15  # Colors within this distance are considered the same
    max_clusters = 30     # Maximum number of semantic classes expected
    
    print(f"Configuration:")
    print(f"  Color tolerance: {color_tolerance}")
    print(f"  Max clusters: {max_clusters}")
    print()
    
    # Count classes across all images
    max_classes, max_image, class_counts = count_classes_in_segmentation_maps(
        folder_path, color_tolerance, max_clusters
    )
    
    if max_classes > 0:
        print(f"\n{'='*50}")
        print(f"RESULTS:")
        print(f"{'='*50}")
        print(f"Maximum number of classes in a single image: {max_classes}")
        print(f"Image with maximum classes: {os.path.basename(max_image) if max_image else 'None'}")
        
        # Show statistics
        counts = [count for _, count in class_counts]
        print(f"\nStatistics across all images:")
        print(f"  Average classes per image: {np.mean(counts):.2f}")
        print(f"  Minimum classes in an image: {np.min(counts)}")
        print(f"  Maximum classes in an image: {np.max(counts)}")
        
        # Show top 10 images with most classes
        print(f"\nTop 10 images with most classes:")
        sorted_counts = sorted(class_counts, key=lambda x: x[1], reverse=True)
        for i, (filename, count) in enumerate(sorted_counts[:10]):
            print(f"  {i+1:2d}. {filename}: {count} classes")
        
        # Analyze the image with maximum classes
        if max_image:
            analyze_specific_image(max_image, color_tolerance, max_clusters)
    else:
        print("No valid images found or processed.")
# Out:
# Configuration:
#   Color tolerance: 15
#   Max clusters: 30
#
# Processing 8862 images...
# Using color tolerance: 15
# Processed 10/8862 images...
# Processed 20/8862 images...
# Processed 30/8862 images...
# Processed 40/8862 images...
# Processed 50/8862 images...
# Processed 60/8862 images...
# Processed 70/8862 images...
# Processed 80/8862 images...
# Processed 90/8862 images...
# Processed 100/8862 images...
# Processed 110/8862 images...
# Processed 120/8862 images...
# Processed 130/8862 images...
# Processed 140/8862 images...
# Processed 150/8862 images...
# Processed 160/8862 images...
# Processed 170/8862 images...
# Processed 180/8862 images...
# Processed 190/8862 images...
# Processed 200/8862 images...
# Processed 210/8862 images...
# Processed 220/8862 images...
# Processed 230/8862 images...
# Processed 240/8862 images...
# Processed 250/8862 images...
# Processed 260/8862 images...
# Processed 270/8862 images...
# Processed 280/8862 images...
# Processed 290/8862 images...
# Processed 300/8862 images...
# Processed 310/8862 images...
# Processed 320/8862 images...
# Processed 330/8862 images...
# Processed 340/8862 images...
# Processed 350/8862 images...
# Processed 360/8862 images...
# Processed 370/8862 images...
# Processed 380/8862 images...
# Processed 390/8862 images...
# Processed 400/8862 images...
# Processed 410/8862 images...
# Processed 420/8862 images...
# Processed 430/8862 images...
# Processed 440/8862 images...
# Processed 450/8862 images...
# Processed 460/8862 images...
# Processed 470/8862 images...
# Processed 480/8862 images...
# Processed 490/8862 images...
# Processed 500/8862 images...
# Processed 510/8862 images...
# Processed 520/8862 images...
# Processed 530/8862 images...
# Processed 540/8862 images...
# Processed 550/8862 images...
# Processed 560/8862 images...
# Processed 570/8862 images...
# Processed 580/8862 images...
# Processed 590/8862 images...
# Processed 600/8862 images...
# Processed 610/8862 images...
# Processed 620/8862 images...
# Processed 630/8862 images...
# Processed 640/8862 images...
# Processed 650/8862 images...
# Processed 660/8862 images...
# Processed 670/8862 images...
# Processed 680/8862 images...
# Processed 690/8862 images...
# Processed 700/8862 images...
# Processed 710/8862 images...
# Processed 720/8862 images...
# Processed 730/8862 images...
# Processed 740/8862 images...
# Processed 750/8862 images...
# Processed 760/8862 images...
# Processed 770/8862 images...
# Processed 780/8862 images...
# Processed 790/8862 images...
# Processed 800/8862 images...
# Processed 810/8862 images...
# Processed 820/8862 images...
# Processed 830/8862 images...
# Processed 840/8862 images...
# Processed 850/8862 images...
# Processed 860/8862 images...
# Processed 870/8862 images...
# Processed 880/8862 images...
# Processed 890/8862 images...
# Processed 900/8862 images...
# Processed 910/8862 images...
# Processed 920/8862 images...
# Processed 930/8862 images...
# Processed 940/8862 images...
# Processed 950/8862 images...
# Processed 960/8862 images...
# Processed 970/8862 images...
# Processed 980/8862 images...
# Processed 990/8862 images...
# Processed 1000/8862 images...
# Processed 1010/8862 images...
# Processed 1020/8862 images...
# Processed 1030/8862 images...
# Processed 1040/8862 images...
# Processed 1050/8862 images...
# Processed 1060/8862 images...
# Processed 1070/8862 images...
# Processed 1080/8862 images...
# Processed 1090/8862 images...
# Processed 1100/8862 images...
# Processed 1110/8862 images...
# Processed 1120/8862 images...
# Processed 1130/8862 images...
# Processed 1140/8862 images...
# Processed 1150/8862 images...
# Processed 1160/8862 images...
# Processed 1170/8862 images...
# Processed 1180/8862 images...
# Processed 1190/8862 images...
# Processed 1200/8862 images...
# Processed 1210/8862 images...
# Processed 1220/8862 images...
# Processed 1230/8862 images...
# Processed 1240/8862 images...
# Processed 1250/8862 images...
# Processed 1260/8862 images...
# Processed 1270/8862 images...
# Processed 1280/8862 images...
# Processed 1290/8862 images...
# Processed 1300/8862 images...
# Processed 1310/8862 images...
# Processed 1320/8862 images...
# Processed 1330/8862 images...
# Processed 1340/8862 images...
# Processed 1350/8862 images...
# Processed 1360/8862 images...
# Processed 1370/8862 images...
# Processed 1380/8862 images...
# Processed 1390/8862 images...
# Processed 1400/8862 images...
# Processed 1410/8862 images...
# Processed 1420/8862 images...
# Processed 1430/8862 images...
# Processed 1440/8862 images...
# Processed 1450/8862 images...
# Processed 1460/8862 images...
# Processed 1470/8862 images...
# Processed 1480/8862 images...
# Processed 1490/8862 images...
# Processed 1500/8862 images...
# Processed 1510/8862 images...
# Processed 1520/8862 images...
# Processed 1530/8862 images...
# Processed 1540/8862 images...
# Processed 1550/8862 images...
# Processed 1560/8862 images...
# Processed 1570/8862 images...
# Processed 1580/8862 images...
# Processed 1590/8862 images...
# Processed 1600/8862 images...
# Processed 1610/8862 images...
# Processed 1620/8862 images...
# Processed 1630/8862 images...
# Processed 1640/8862 images...
# Processed 1650/8862 images...
# Processed 1660/8862 images...
# Processed 1670/8862 images...
# Processed 1680/8862 images...
# Processed 1690/8862 images...
# Processed 1700/8862 images...
# Processed 1710/8862 images...
# Processed 1720/8862 images...
# Processed 1730/8862 images...
# Processed 1740/8862 images...
# Processed 1750/8862 images...
# Processed 1760/8862 images...
# Processed 1770/8862 images...
# Processed 1780/8862 images...
# Processed 1790/8862 images...
# Processed 1800/8862 images...
# Processed 1810/8862 images...
# Processed 1820/8862 images...
# Processed 1830/8862 images...
# Processed 1840/8862 images...
# Processed 1850/8862 images...
# Processed 1860/8862 images...
# Processed 1870/8862 images...
# Processed 1880/8862 images...
# Processed 1890/8862 images...
# Processed 1900/8862 images...
# Processed 1910/8862 images...
# Processed 1920/8862 images...
# Processed 1930/8862 images...
# Processed 1940/8862 images...
# Processed 1950/8862 images...
# Processed 1960/8862 images...
# Processed 1970/8862 images...
# Processed 1980/8862 images...
# Processed 1990/8862 images...
# Processed 2000/8862 images...
# Processed 2010/8862 images...
# Processed 2020/8862 images...
# Processed 2030/8862 images...
# Processed 2040/8862 images...
# Processed 2050/8862 images...
# Processed 2060/8862 images...
# Processed 2070/8862 images...
# Processed 2080/8862 images...
# Processed 2090/8862 images...
# Processed 2100/8862 images...
# Processed 2110/8862 images...
# Processed 2120/8862 images...
# Processed 2130/8862 images...
# Processed 2140/8862 images...
# Processed 2150/8862 images...
# Processed 2160/8862 images...
# Processed 2170/8862 images...
# Processed 2180/8862 images...
# Processed 2190/8862 images...
# Processed 2200/8862 images...
# Processed 2210/8862 images...
# Processed 2220/8862 images...
# Processed 2230/8862 images...
# Processed 2240/8862 images...
# Processed 2250/8862 images...
# Processed 2260/8862 images...
# Processed 2270/8862 images...
# Processed 2280/8862 images...
# Processed 2290/8862 images...
# Processed 2300/8862 images...
# Processed 2310/8862 images...
# Processed 2320/8862 images...
# Processed 2330/8862 images...
# Processed 2340/8862 images...
# Processed 2350/8862 images...
# Processed 2360/8862 images...
# Processed 2370/8862 images...
# Processed 2380/8862 images...
# Processed 2390/8862 images...
# Processed 2400/8862 images...
# Processed 2410/8862 images...
# Processed 2420/8862 images...
# Processed 2430/8862 images...
# Processed 2440/8862 images...
# Processed 2450/8862 images...
# Processed 2460/8862 images...
# Processed 2470/8862 images...
# Processed 2480/8862 images...
# Processed 2490/8862 images...
# Processed 2500/8862 images...
# Processed 2510/8862 images...
# Processed 2520/8862 images...
# Processed 2530/8862 images...
# Processed 2540/8862 images...
# Processed 2550/8862 images...
# Processed 2560/8862 images...
# Processed 2570/8862 images...
# Processed 2580/8862 images...
# Processed 2590/8862 images...
# Processed 2600/8862 images...
# Processed 2610/8862 images...
# Processed 2620/8862 images...
# Processed 2630/8862 images...
# Processed 2640/8862 images...
# Processed 2650/8862 images...
# Processed 2660/8862 images...
# Processed 2670/8862 images...
# Processed 2680/8862 images...
# Processed 2690/8862 images...
# Processed 2700/8862 images...
# Processed 2710/8862 images...
# Processed 2720/8862 images...
# Processed 2730/8862 images...
# Processed 2740/8862 images...
# Processed 2750/8862 images...
# Processed 2760/8862 images...
# Processed 2770/8862 images...
# Processed 2780/8862 images...
# Processed 2790/8862 images...
# Processed 2800/8862 images...
# Processed 2810/8862 images...
# Processed 2820/8862 images...
# Processed 2830/8862 images...
# Processed 2840/8862 images...
# Processed 2850/8862 images...
# Processed 2860/8862 images...
# Processed 2870/8862 images...
# Processed 2880/8862 images...
# Processed 2890/8862 images...
# Processed 2900/8862 images...
# Processed 2910/8862 images...
# Processed 2920/8862 images...
# Processed 2930/8862 images...
# Processed 2940/8862 images...
# Processed 2950/8862 images...
# Processed 2960/8862 images...
# Processed 2970/8862 images...
# Processed 2980/8862 images...
# Processed 2990/8862 images...
# Processed 3000/8862 images...
# Processed 3010/8862 images...
# Processed 3020/8862 images...
# Processed 3030/8862 images...
# Processed 3040/8862 images...
# Processed 3050/8862 images...
# Processed 3060/8862 images...
# Processed 3070/8862 images...
# Processed 3080/8862 images...
# Processed 3090/8862 images...
# Processed 3100/8862 images...
# Processed 3110/8862 images...
# Processed 3120/8862 images...
# Processed 3130/8862 images...
# Processed 3140/8862 images...
# Processed 3150/8862 images...
# Processed 3160/8862 images...
# Processed 3170/8862 images...
# Processed 3180/8862 images...
# Processed 3190/8862 images...
# Processed 3200/8862 images...
# Processed 3210/8862 images...
# Processed 3220/8862 images...
# Processed 3230/8862 images...
# Processed 3240/8862 images...
# Processed 3250/8862 images...
# Processed 3260/8862 images...
# Processed 3270/8862 images...
# Processed 3280/8862 images...
# Processed 3290/8862 images...
# Processed 3300/8862 images...
# Processed 3310/8862 images...
# Processed 3320/8862 images...
# Processed 3330/8862 images...
# Processed 3340/8862 images...
# Processed 3350/8862 images...
# Processed 3360/8862 images...
# Processed 3370/8862 images...
# Processed 3380/8862 images...
# Processed 3390/8862 images...
# Processed 3400/8862 images...
# Processed 3410/8862 images...
# Processed 3420/8862 images...
# Processed 3430/8862 images...
# Processed 3440/8862 images...
# Processed 3450/8862 images...
# Processed 3460/8862 images...
# Processed 3470/8862 images...
# Processed 3480/8862 images...
# Processed 3490/8862 images...
# Processed 3500/8862 images...
# Processed 3510/8862 images...
# Processed 3520/8862 images...
# Processed 3530/8862 images...
# Processed 3540/8862 images...
# Processed 3550/8862 images...
# Processed 3560/8862 images...
# Processed 3570/8862 images...
# Processed 3580/8862 images...
# Processed 3590/8862 images...
# Processed 3600/8862 images...
# Processed 3610/8862 images...
# Processed 3620/8862 images...
# Processed 3630/8862 images...
# Processed 3640/8862 images...
# Processed 3650/8862 images...
# Processed 3660/8862 images...
# Processed 3670/8862 images...
# Processed 3680/8862 images...
# Processed 3690/8862 images...
# Processed 3700/8862 images...
# Processed 3710/8862 images...
# Processed 3720/8862 images...
# Processed 3730/8862 images...
# Processed 3740/8862 images...
# Processed 3750/8862 images...
# Processed 3760/8862 images...
# Processed 3770/8862 images...
# Processed 3780/8862 images...
# Processed 3790/8862 images...
# Processed 3800/8862 images...
# Processed 3810/8862 images...
# Processed 3820/8862 images...
# Processed 3830/8862 images...
# Processed 3840/8862 images...
# Processed 3850/8862 images...
# Processed 3860/8862 images...
# Processed 3870/8862 images...
# Processed 3880/8862 images...
# Processed 3890/8862 images...
# Processed 3900/8862 images...
# Processed 3910/8862 images...
# Processed 3920/8862 images...
# Processed 3930/8862 images...
# Processed 3940/8862 images...
# Processed 3950/8862 images...
# Processed 3960/8862 images...
# Processed 3970/8862 images...
# Processed 3980/8862 images...
# Processed 3990/8862 images...
# Processed 4000/8862 images...
# Processed 4010/8862 images...
# Processed 4020/8862 images...
# Processed 4030/8862 images...
# Processed 4040/8862 images...
# Processed 4050/8862 images...
# Processed 4060/8862 images...
# Processed 4070/8862 images...
# Processed 4080/8862 images...
# Processed 4090/8862 images...
# Processed 4100/8862 images...
# Processed 4110/8862 images...
# Processed 4120/8862 images...
# Processed 4130/8862 images...
# Processed 4140/8862 images...
# Processed 4150/8862 images...
# Processed 4160/8862 images...
# Processed 4170/8862 images...
# Processed 4180/8862 images...
# Processed 4190/8862 images...
# Processed 4200/8862 images...
# Processed 4210/8862 images...
# Processed 4220/8862 images...
# Processed 4230/8862 images...
# Processed 4240/8862 images...
# Processed 4250/8862 images...
# Processed 4260/8862 images...
# Processed 4270/8862 images...
# Processed 4280/8862 images...
# Processed 4290/8862 images...
# Processed 4300/8862 images...
# Processed 4310/8862 images...
# Processed 4320/8862 images...
# Processed 4330/8862 images...
# Processed 4340/8862 images...
# Processed 4350/8862 images...
# Processed 4360/8862 images...
# Processed 4370/8862 images...
# Processed 4380/8862 images...
# Processed 4390/8862 images...
# Processed 4400/8862 images...
# Processed 4410/8862 images...
# Processed 4420/8862 images...
# Processed 4430/8862 images...
# Processed 4440/8862 images...
# Processed 4450/8862 images...
# Processed 4460/8862 images...
# Processed 4470/8862 images...
# Processed 4480/8862 images...
# Processed 4490/8862 images...
# Processed 4500/8862 images...
# Processed 4510/8862 images...
# Processed 4520/8862 images...
# Processed 4530/8862 images...
# Processed 4540/8862 images...
# Processed 4550/8862 images...
# Processed 4560/8862 images...
# Processed 4570/8862 images...
# Processed 4580/8862 images...
# Processed 4590/8862 images...
# Processed 4600/8862 images...
# Processed 4610/8862 images...
# Processed 4620/8862 images...
# Processed 4630/8862 images...
# Processed 4640/8862 images...
# Processed 4650/8862 images...
# Processed 4660/8862 images...
# Processed 4670/8862 images...
# Processed 4680/8862 images...
# Processed 4690/8862 images...
# Processed 4700/8862 images...
# Processed 4710/8862 images...
# Processed 4720/8862 images...
# Processed 4730/8862 images...
# Processed 4740/8862 images...
# Processed 4750/8862 images...
# Processed 4760/8862 images...
# Processed 4770/8862 images...
# Processed 4780/8862 images...
# Processed 4790/8862 images...
# Processed 4800/8862 images...
# Processed 4810/8862 images...
# Processed 4820/8862 images...
# Processed 4830/8862 images...
# Processed 4840/8862 images...
# Processed 4850/8862 images...
# Processed 4860/8862 images...
# Processed 4870/8862 images...
# Processed 4880/8862 images...
# Processed 4890/8862 images...
# Processed 4900/8862 images...
# Processed 4910/8862 images...
# Processed 4920/8862 images...
# Processed 4930/8862 images...
# Processed 4940/8862 images...
# Processed 4950/8862 images...
# Processed 4960/8862 images...
# Processed 4970/8862 images...
# Processed 4980/8862 images...
# Processed 4990/8862 images...
# Processed 5000/8862 images...
# Processed 5010/8862 images...
# Processed 5020/8862 images...
# Processed 5030/8862 images...
# Processed 5040/8862 images...
# Processed 5050/8862 images...
# Processed 5060/8862 images...
# Processed 5070/8862 images...
# Processed 5080/8862 images...
# Processed 5090/8862 images...
# Processed 5100/8862 images...
# Processed 5110/8862 images...
# Processed 5120/8862 images...
# Processed 5130/8862 images...
# Processed 5140/8862 images...
# Processed 5150/8862 images...
# Processed 5160/8862 images...
# Processed 5170/8862 images...
# Processed 5180/8862 images...
# Processed 5190/8862 images...
# Processed 5200/8862 images...
# Processed 5210/8862 images...
# Processed 5220/8862 images...
# Processed 5230/8862 images...
# Processed 5240/8862 images...
# Processed 5250/8862 images...
# Processed 5260/8862 images...
# Processed 5270/8862 images...
# Processed 5280/8862 images...
# Processed 5290/8862 images...
# Processed 5300/8862 images...
# Processed 5310/8862 images...
# Processed 5320/8862 images...
# Processed 5330/8862 images...
# Processed 5340/8862 images...
# Processed 5350/8862 images...
# Processed 5360/8862 images...
# Processed 5370/8862 images...
# Processed 5380/8862 images...
# Processed 5390/8862 images...
# Processed 5400/8862 images...
# Processed 5410/8862 images...
# Processed 5420/8862 images...
# Processed 5430/8862 images...
# Processed 5440/8862 images...
# Processed 5450/8862 images...
# Processed 5460/8862 images...
# Processed 5470/8862 images...
# Processed 5480/8862 images...
# Processed 5490/8862 images...
# Processed 5500/8862 images...
# Processed 5510/8862 images...
# Processed 5520/8862 images...
# Processed 5530/8862 images...
# Processed 5540/8862 images...
# Processed 5550/8862 images...
# Processed 5560/8862 images...
# Processed 5570/8862 images...
# Processed 5580/8862 images...
# Processed 5590/8862 images...
# Processed 5600/8862 images...
# Processed 5610/8862 images...
# Processed 5620/8862 images...
# Processed 5630/8862 images...
# Processed 5640/8862 images...
# Processed 5650/8862 images...
# Processed 5660/8862 images...
# Processed 5670/8862 images...
# Processed 5680/8862 images...
# Processed 5690/8862 images...
# Processed 5700/8862 images...
# Processed 5710/8862 images...
# Processed 5720/8862 images...
# Processed 5730/8862 images...
# Processed 5740/8862 images...
# Processed 5750/8862 images...
# Processed 5760/8862 images...
# Processed 5770/8862 images...
# Processed 5780/8862 images...
# Processed 5790/8862 images...
# Processed 5800/8862 images...
# Processed 5810/8862 images...
# Processed 5820/8862 images...
# Processed 5830/8862 images...
# Processed 5840/8862 images...
# Processed 5850/8862 images...
# Processed 5860/8862 images...
# Processed 5870/8862 images...
# Processed 5880/8862 images...
# Processed 5890/8862 images...
# Processed 5900/8862 images...
# Processed 5910/8862 images...
# Processed 5920/8862 images...
# Processed 5930/8862 images...
# Processed 5940/8862 images...
# Processed 5950/8862 images...
# Processed 5960/8862 images...
# Processed 5970/8862 images...
# Processed 5980/8862 images...
# Processed 5990/8862 images...
# Processed 6000/8862 images...
# Processed 6010/8862 images...
# Processed 6020/8862 images...
# Processed 6030/8862 images...
# Processed 6040/8862 images...
# Processed 6050/8862 images...
# Processed 6060/8862 images...
# Processed 6070/8862 images...
# Processed 6080/8862 images...
# Processed 6090/8862 images...
# Processed 6100/8862 images...
# Processed 6110/8862 images...
# Processed 6120/8862 images...
# Processed 6130/8862 images...
# Processed 6140/8862 images...
# Processed 6150/8862 images...
# Processed 6160/8862 images...
# Processed 6170/8862 images...
# Processed 6180/8862 images...
# Processed 6190/8862 images...
# Processed 6200/8862 images...
# Processed 6210/8862 images...
# Processed 6220/8862 images...
# Processed 6230/8862 images...
# Processed 6240/8862 images...
# Processed 6250/8862 images...
# Processed 6260/8862 images...
# Processed 6270/8862 images...
# Processed 6280/8862 images...
# Processed 6290/8862 images...
# Processed 6300/8862 images...
# Processed 6310/8862 images...
# Processed 6320/8862 images...
# Processed 6330/8862 images...
# Processed 6340/8862 images...
# Processed 6350/8862 images...
# Processed 6360/8862 images...
# Processed 6370/8862 images...
# Processed 6380/8862 images...
# Processed 6390/8862 images...
# Processed 6400/8862 images...
# Processed 6410/8862 images...
# Processed 6420/8862 images...
# Processed 6430/8862 images...
# Processed 6440/8862 images...
# Processed 6450/8862 images...
# Processed 6460/8862 images...
# Processed 6470/8862 images...
# Processed 6480/8862 images...
# Processed 6490/8862 images...
# Processed 6500/8862 images...
# Processed 6510/8862 images...
# Processed 6520/8862 images...
# Processed 6530/8862 images...
# Processed 6540/8862 images...
# Processed 6550/8862 images...
# Processed 6560/8862 images...
# Processed 6570/8862 images...
# Processed 6580/8862 images...
# Processed 6590/8862 images...
# Processed 6600/8862 images...
# Processed 6610/8862 images...
# Processed 6620/8862 images...
# Processed 6630/8862 images...
# Processed 6640/8862 images...
# Processed 6650/8862 images...
# Processed 6660/8862 images...
# Processed 6670/8862 images...
# Processed 6680/8862 images...
# Processed 6690/8862 images...
# Processed 6700/8862 images...
# Processed 6710/8862 images...
# Processed 6720/8862 images...
# Processed 6730/8862 images...
# Processed 6740/8862 images...
# Processed 6750/8862 images...
# Processed 6760/8862 images...
# Processed 6770/8862 images...
# Processed 6780/8862 images...
# Processed 6790/8862 images...
# Processed 6800/8862 images...
# Processed 6810/8862 images...
# Processed 6820/8862 images...
# Processed 6830/8862 images...
# Processed 6840/8862 images...
# Processed 6850/8862 images...
# Processed 6860/8862 images...
# Processed 6870/8862 images...
# Processed 6880/8862 images...
# Processed 6890/8862 images...
# Processed 6900/8862 images...
# Processed 6910/8862 images...
# Processed 6920/8862 images...
# Processed 6930/8862 images...
# Processed 6940/8862 images...
# Processed 6950/8862 images...
# Processed 6960/8862 images...
# Processed 6970/8862 images...
# Processed 6980/8862 images...
# Processed 6990/8862 images...
# Processed 7000/8862 images...
# Processed 7010/8862 images...
# Processed 7020/8862 images...
# Processed 7030/8862 images...
# Processed 7040/8862 images...
# Processed 7050/8862 images...
# Processed 7060/8862 images...
# Processed 7070/8862 images...
# Processed 7080/8862 images...
# Processed 7090/8862 images...
# Processed 7100/8862 images...
# Processed 7110/8862 images...
# Processed 7120/8862 images...
# Processed 7130/8862 images...
# Processed 7140/8862 images...
# Processed 7150/8862 images...
# Processed 7160/8862 images...
# Processed 7170/8862 images...
# Processed 7180/8862 images...
# Processed 7190/8862 images...
# Processed 7200/8862 images...
# Processed 7210/8862 images...
# Processed 7220/8862 images...
# Processed 7230/8862 images...
# Processed 7240/8862 images...
# Processed 7250/8862 images...
# Processed 7260/8862 images...
# Processed 7270/8862 images...
# Processed 7280/8862 images...
# Processed 7290/8862 images...
# Processed 7300/8862 images...
# Processed 7310/8862 images...
# Processed 7320/8862 images...
# Processed 7330/8862 images...
# Processed 7340/8862 images...
# Processed 7350/8862 images...
# Processed 7360/8862 images...
# Processed 7370/8862 images...
# Processed 7380/8862 images...
# Processed 7390/8862 images...
# Processed 7400/8862 images...
# Processed 7410/8862 images...
# Processed 7420/8862 images...
# Processed 7430/8862 images...
# Processed 7440/8862 images...
# Processed 7450/8862 images...
# Processed 7460/8862 images...
# Processed 7470/8862 images...
# Processed 7480/8862 images...
# Processed 7490/8862 images...
# Processed 7500/8862 images...
# Processed 7510/8862 images...
# Processed 7520/8862 images...
# Processed 7530/8862 images...
# Processed 7540/8862 images...
# Processed 7550/8862 images...
# Processed 7560/8862 images...
# Processed 7570/8862 images...
# Processed 7580/8862 images...
# Processed 7590/8862 images...
# Processed 7600/8862 images...
# Processed 7610/8862 images...
# Processed 7620/8862 images...
# Processed 7630/8862 images...
# Processed 7640/8862 images...
# Processed 7650/8862 images...
# Processed 7660/8862 images...
# Processed 7670/8862 images...
# Processed 7680/8862 images...
# Processed 7690/8862 images...
# Processed 7700/8862 images...
# Processed 7710/8862 images...
# Processed 7720/8862 images...
# Processed 7730/8862 images...
# Processed 7740/8862 images...
# Processed 7750/8862 images...
# Processed 7760/8862 images...
# Processed 7770/8862 images...
# Processed 7780/8862 images...
# Processed 7790/8862 images...
# Processed 7800/8862 images...
# Processed 7810/8862 images...
# Processed 7820/8862 images...
# Processed 7830/8862 images...
# Processed 7840/8862 images...
# Processed 7850/8862 images...
# Processed 7860/8862 images...
# Processed 7870/8862 images...
# Processed 7880/8862 images...
# Processed 7890/8862 images...
# Processed 7900/8862 images...
# Processed 7910/8862 images...
# Processed 7920/8862 images...
# Processed 7930/8862 images...
# Processed 7940/8862 images...
# Processed 7950/8862 images...
# Processed 7960/8862 images...
# Processed 7970/8862 images...
# Processed 7980/8862 images...
# Processed 7990/8862 images...
# Processed 8000/8862 images...
# Processed 8010/8862 images...
# Processed 8020/8862 images...
# Processed 8030/8862 images...
# Processed 8040/8862 images...
# Processed 8050/8862 images...
# Processed 8060/8862 images...
# Processed 8070/8862 images...
# Processed 8080/8862 images...
# Processed 8090/8862 images...
# Processed 8100/8862 images...
# Processed 8110/8862 images...
# Processed 8120/8862 images...
# Processed 8130/8862 images...
# Processed 8140/8862 images...
# Processed 8150/8862 images...
# Processed 8160/8862 images...
# Processed 8170/8862 images...
# Processed 8180/8862 images...
# Processed 8190/8862 images...
# Processed 8200/8862 images...
# Processed 8210/8862 images...
# Processed 8220/8862 images...
# Processed 8230/8862 images...
# Processed 8240/8862 images...
# Processed 8250/8862 images...
# Processed 8260/8862 images...
# Processed 8270/8862 images...
# Processed 8280/8862 images...
# Processed 8290/8862 images...
# Processed 8300/8862 images...
# Processed 8310/8862 images...
# Processed 8320/8862 images...
# Processed 8330/8862 images...
# Processed 8340/8862 images...
# Processed 8350/8862 images...
# Processed 8360/8862 images...
# Processed 8370/8862 images...
# Processed 8380/8862 images...
# Processed 8390/8862 images...
# Processed 8400/8862 images...
# Processed 8410/8862 images...
# Processed 8420/8862 images...
# Processed 8430/8862 images...
# Processed 8440/8862 images...
# Processed 8450/8862 images...
# Processed 8460/8862 images...
# Processed 8470/8862 images...
# Processed 8480/8862 images...
# Processed 8490/8862 images...
# Processed 8500/8862 images...
# Processed 8510/8862 images...
# Processed 8520/8862 images...
# Processed 8530/8862 images...
# Processed 8540/8862 images...
# Processed 8550/8862 images...
# Processed 8560/8862 images...
# Processed 8570/8862 images...
# Processed 8580/8862 images...
# Processed 8590/8862 images...
# Processed 8600/8862 images...
# Processed 8610/8862 images...
# Processed 8620/8862 images...
# Processed 8630/8862 images...
# Processed 8640/8862 images...
# Processed 8650/8862 images...
# Processed 8660/8862 images...
# Processed 8670/8862 images...
# Processed 8680/8862 images...
# Processed 8690/8862 images...
# Processed 8700/8862 images...
# Processed 8710/8862 images...
# Processed 8720/8862 images...
# Processed 8730/8862 images...
# Processed 8740/8862 images...
# Processed 8750/8862 images...
# Processed 8760/8862 images...
# Processed 8770/8862 images...
# Processed 8780/8862 images...
# Processed 8790/8862 images...
# Processed 8800/8862 images...
# Processed 8810/8862 images...
# Processed 8820/8862 images...
# Processed 8830/8862 images...
# Processed 8840/8862 images...
# Processed 8850/8862 images...
# Processed 8860/8862 images...
#
# ==================================================
# RESULTS:
# ==================================================
# Maximum number of classes in a single image: 30
# Image with maximum classes: output0000008.png
#
# Statistics across all images:
#   Average classes per image: 29.91
#   Minimum classes in an image: 1
#   Maximum classes in an image: 30
#
# Top 10 images with most classes:
#    1. output0000008.png: 30 classes
#    2. output0000029.png: 30 classes
#    3. output0000035.png: 30 classes
#    4. output0000052.png: 30 classes
#    5. output0000068.png: 30 classes
#    6. output0000075.png: 30 classes
#    7. output0000078.png: 30 classes
#    8. output0000082.png: 30 classes
#    9. output0000094.png: 30 classes
#   10. output0000101.png: 30 classes
#
# Analyzing: output0000008.png
# Image shape: (128, 512, 3)
# Raw unique colors: 1728
# Clustered unique colors (tolerance=15): 30
# Most common colors:
#   1. RGB(np.uint8(0), np.uint8(255), np.uint8(255)): 22693 pixels (34.6%)
#   2. RGB(np.uint8(0), np.uint8(255), np.uint8(0)): 17620 pixels (26.9%)
#   3. RGB(np.uint8(255), np.uint8(255), np.uint8(255)): 15426 pixels (23.5%)
#   4. RGB(np.uint8(0), np.uint8(0), np.uint8(255)): 1046 pixels (1.6%)
#   5. RGB(np.uint8(0), np.uint8(255), np.uint8(254)): 257 pixels (0.4%)
#   6. RGB(np.uint8(254), np.uint8(255), np.uint8(254)): 224 pixels (0.3%)
#   7. RGB(np.uint8(254), np.uint8(255), np.uint8(255)): 192 pixels (0.3%)
#   8. RGB(np.uint8(255), np.uint8(0), np.uint8(0)): 178 pixels (0.3%)
#   9. RGB(np.uint8(0), np.uint8(255), np.uint8(253)): 97 pixels (0.1%)
#   10. RGB(np.uint8(0), np.uint8(255), np.uint8(1)): 91 pixels (0.1%)
